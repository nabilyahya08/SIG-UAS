# %%
# Mengimport modul warnings
import warnings
# Semua pesan peringatan selama eksekusi program akan diabaikan dan tidak ditampilkan.
warnings.filterwarnings('ignore')

# %%
# Menginstall modul geopandas
# !pip install geopandas
# Mengimport modul geopandas dengan alias gpd
import geopandas as gpd

# %%
# Membaca file geojson dan disimpan ke variabel gdf
gdf = gpd.read_file('RBI25K_ADMINISTRASI_AR.geojson')
# Menampilkan lima baris pertama dari variabel gdf
gdf.head()
# Out:
#          NAMOBJ       FCODE REMARK                                METADATA  \
# 0       Cilacap  BA03040060   None  TASWIL2500020210531_DATA_BATAS_KABKOTA
# 1  Banjarnegara  BA03040060   None  TASWIL2500020210531_DATA_BATAS_KABKOTA
# 2       Kebumen  BA03040060   None  TASWIL2500020210531_DATA_BATAS_KABKOTA
# 3      Wonosobo  BA03040060   None  TASWIL2500020210531_DATA_BATAS_KABKOTA
# 4   Purbalingga  BA03040060   None  TASWIL2500020210531_DATA_BATAS_KABKOTA
#
#   SRS_ID KDBBPS KDCBPS KDCPUM KDEBPS KDEPUM  ... WADMKD        WADMKK  \
# 0   None   None   None   None   None   None  ...   None       Cilacap
# 1   None   None   None   None   None   None  ...   None  Banjarnegara
# 2   None   None   None   None   None   None  ...   None       Kebumen
# 3   None   None   None   None   None   None  ...   None      Wonosobo
# 4   None   None   None   None   None   None  ...   None   Purbalingga
#
#         WADMPR  WIADKC  WIADKK WIADPR WIADKD SHAPE_AREA SHAPE_LEN  \
# ...

# %%
# Memilih kolom 'NAMOBJ', 'FCODE', 'REMARK', 'METADATA', dan 'geometry' dan menggantikan nilai NaN menjadi 0
gdf = gdf[['NAMOBJ', 'FCODE', 'REMARK', 'METADATA', 'geometry']].fillna(0)

# %%
# Menginstall modul folium, matplotlib dan mapclassify
# !pip install folium matplotlib mapclassify
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 97.0/97.0 kB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.6/7.6 MB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 56.3/56.3 kB 2.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 62.6/62.6 kB 3.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 133.1/133.1 kB 3.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.2/2.2 MB 3.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.6/2.6 MB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 56.1/56.1 kB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 103.1/103.1 kB 2.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 186.7/186.7 kB 1.9 MB/s eta 0:00:00
# ...

# %%
# Mengimport modul folium
import folium

# Membuat map menggunakan folium dan disimpan ke variabel m
m = gdf.explore(column="METADATA", name="Metadata")
# Menambahkan layer control ke objek map dengan variabel m
folium.LayerControl().add_to(m)
# Menampilkan map
m
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
